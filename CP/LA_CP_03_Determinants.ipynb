# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/LPolyakova/Linear_Algebra_for_CS_students/blob/main/CP/LA_03_Determinants.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # ЛА-Комп'ютерний практикум-03. Визначники

# %%
# these imports may be useful

import pandas as pd
from scipy import linalg
import numpy as np
import matplotlib.pyplot as plt
from sympy import *                  #module to do symbolic calculations

# %% [markdown]
#  #### Деякі інструменти, що стануть у нагоді

# %%
# these tools may be useful
# determinant calculation
A = np.array([[1, 2, 3], [0, 1, 3], [2, 4, 0]])
d = linalg.det(A)
print(f'''Determinant of matrix A={A} equals {d}''')
# Out:
# Determinant of matrix A=[[1 2 3]
#  [0 1 3]
#  [2 4 0]] equals -6.0

# %% [markdown]
# ## Вправи

# %% [markdown]
# 💻  **3.1. Калькулятор підстановок**
#
# Створіть калькулятор для підстановок. Напишіть код функцій для
#
# 1) обчислення добутку підстановок;
# 2) обчислення оберненої підстановки;
# 3) розкладу підстановки в добуток незалежних циклів та нерухомих елементів;
# 4) розкладу підстановки в добуток транспозицій;
# 5) знаходження знаку (парності) підстановки;
# 6) піднесення підстановки до степеня.

# %%
#write your code here

# %% [markdown]
# 💻  **3.2. Площа паралелограма**
#
# Три вершини паралелограма $ABCD$ задано координатами: $A(x_A, y_A), B(x_B, y_B), C(x_C, y_C)$ в стандартній прямокутній системі координат.
#
# 1. Виразіть координати вершини $D(x_{D} ,y_{D} )$ через координати інших трьох вершин і напишіть код функції, яка отримує на вході координати вершин $A,B,C$, обчислює вершину $D(x_{D} ,y_{D} )$ і малює паралелограм на площині.
#
#
# 2. Доведіть, що площу паралелограма $ABCD$ можна обчислити як модуль визначника ${\displaystyle \begin{vmatrix}
# x_{B} -x_{A} & x_{D} -x_{A}\\
# y_{B} -y_{A} & y_{D} -y_{A}
# \end{vmatrix}}$, тобто визначника, складеного з координат векторів $\overrightarrow{AB}$ та $\overrightarrow{AD}$ . Користуючись цим, напишіть код функції, яка обчислює площу паралелограма $ABCD$ за заданими координатами його вершин.

# %% [markdown]
# ✔️ *Ваші міркування запишіть тут.*

# %%
#write your code here

# %% [markdown]
# 💻  **3.3. Взаємне розташування точок**
#
# 1️⃣ Доведіть, що три точки на площині $A(x_1, y_1), B(x_2, y_2), C(x_3, y_3)$ належать одній прямій тоді й лише тоді, коли $\displaystyle \left| \begin{array}{ c c }
# x_{2} -x_{1} & x_{3} -x_{1}\\
# y_{2} -y_{1} & y_{3} -y_{1}
# \end{array}\right| =\ \left| \begin{array}{ c c c }
# x_{1} & y_{1} & 1\\
# x_{2} & y_{2} & 1\\
# x_{3} & y_{3} & 1
# \end{array}\right| =0$.
#
# Аналогічно доведіть, що точки простору $A( x_{1} ,y_{1} ,z_{1}) , B( x_{2} , y_{2} , z_{2}) , C( x_{3} , y_{3} ,z_{3}) ,D( x_{4} , y_{4} , z_{4})$ належать одній площині тоді й лише тоді, коли $ \left| \begin{array}{ c c c }
# x_{2} -x_{1} & x_{3} -x_{1} & x_{4} -x_{1}\\
# y_{2} -y_{1} & y_{3} -y_{1} & y_{4} -y_{1}\\
# z_{2} -z_{1} & z_{3} -z_{1} & z_{4} -z_{1}
# \end{array}\right| =\ 0$
#
# Або ж еквівалентно $\displaystyle \left| \begin{array}{ c c c c }
# x_{1} & y_{1} & z_{1} & 1\\
# x_{2} & y_{2} & z_{2} & 1\\
# x_{3} & y_{3} & z_{3} & 1\\
# x_{4} & y_{4} & z_{4} & 1
# \end{array}\right| =0$.

# %% [markdown]
# ✔️ *Ваші міркування запишіть тут.*

# %% [markdown]
# 2️⃣ Напишіть програми, які перевіряють, чи належать три точки площини одній прямій; чи належать чотири точки простору одній площині. Проілюструйте роботу програм прикладами.

# %%
#write your code here

# %% [markdown]
# 💻  **3.4. Формули Крамера**
#
# Напишіть програму, яка отримує на вхід систему $n$ лінійних рівнянь з $n$ невідомими (наприклад, у вигляді матриці та вектора правої частини) та обчислює розв'язок цієї системи за допомогою правил Крамера або ж повідомляє, що не може видати розв'язок (у випадку, коли головний визначник системи дорівнює 0). Для обчислення визначників використовуйте вбудовані функції. Порівняйте час знаходження розв'язку за допомогою вашої функції та за допомогою вбудованих засобів розв'язання систем (таких як np.linalg.solve). Порівнювати варто на згенерованих 'великих' тестових матрицях з випадковими елементами.

# %%
#write your code here

# %% [markdown]
# 💻  **3.5. Вандермонд**
#
# 1. Напишіть код функції, яка за даним вектором значень  $x=(x_1, \dots, x_n)$ створює матрицю Вандермонда $W(x_1, \dots, x_n)$. Не використовуйте вбудовані функції (такі як numpy.vander
# , але можете потім порявняти свій результат з тим, що роблять вбудовані функції.
#
# 2. Напишіть код функції, яка обчислює визначник Вандермонда $\det W(x_1, \dots, x_n)$. Передбачте два варіанти: якщо на вхід подається вектор $x=(x_1, \dots, x_n)$, або ж уже готова матриця  $W(x_1, \dots, x_n)$.)

# %%
#write your code here

# %% [markdown]
# 💻  **3.6. Методи обчислення визначників**
#
# Напишіть код для трьох функцій:
#
# 1. det_Laplace, яка рекурсивно обчислює визначник матриці за допомогою розкладання за рядком (стовпчиком).
# 2. det_Gauss, яка обчислює визначник матриці за допомогою зведення матриці до трикутного вигляду.
# 3. det_permutation, яка обчислює визначник матриці як суму $n!$ добутків елементів матриці (по одному з кожного рядка й кожного стовпця) зі знаками, що визначаються знаками підстановок індексів.
#
# Порівняйте швидкодію цих методів на визначниках достатньо великого порядку з випадковими елементами.
#
# НЕ використовуйте вбудовані засоби обчислення визначників.

# %%
#write your code here
